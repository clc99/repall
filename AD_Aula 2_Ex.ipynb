# %%
##############################################################
##Análise de Dados - AULA 2
##############################################################
##Exemplos 1 e 2    
##############################################################
filhos<-c(0,1,3,4,2,1,1,2,3,2,2,3,2,2,1,5,3,2,3,2,4,2,2,5,3)
tab.f<-table(filhos)
tab.f
plot(tab.f, main = "Histograma", xlab = "número de filhos por família",
     ylab = "Frequência", col = "blue", type = "h",
     lwd = 5)
# Out:
# filhos
#  0  1  2  3  4  5
#  1  4 10  6  2  2
# Plot with title “Histograma”
